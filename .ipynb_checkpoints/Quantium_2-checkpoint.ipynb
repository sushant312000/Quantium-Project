# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("QVI_data.csv")
data
# Out:
#         LYLTY_CARD_NBR        DATE  STORE_NBR  TXN_ID  PROD_NBR  \
# 0                 1000  17-10-2018          1       1         5
# 1                 1002  16-09-2018          1       2        58
# 2                 1003  07-03-2019          1       3        52
# 3                 1003  08-03-2019          1       4       106
# 4                 1004  02-11-2018          1       5        96
# ...                ...         ...        ...     ...       ...
# 264829         2370701  08-12-2018         88  240378        24
# 264830         2370751  01-10-2018         88  240394        60
# 264831         2370961  24-10-2018         88  240480        70
# 264832         2370961  27-10-2018         88  240481        65
# 264833         2373711  14-12-2018         88  241815        16
#
#                                        PROD_NAME  PROD_QTY  TOT_SALES  \
# 0         Natural Chip        Compny SeaSalt175g         2        6.0
# ...

# %%
data_77 = data[data['STORE_NBR']==77]
data_77
# Out:
#         LYLTY_CARD_NBR        DATE  STORE_NBR  TXN_ID  PROD_NBR  \
# 73365            77000  28-03-2019         77   74911        18
# 73366            77000  13-04-2019         77   74912        69
# 73367            77000  26-09-2018         77   74910        36
# 73368            77001  27-02-2019         77   74913         7
# 73369            77001  21-01-2019         77   74914         9
# ...                ...         ...        ...     ...       ...
# 264818         2330321  30-07-2018         77  236756        71
# 264819         2330331  18-11-2018         77  236760        95
# 264820         2330431  31-07-2018         77  236770        50
# 264821         2330461  21-07-2018         77  236777        87
# 264822         2330501  20-06-2019         77  236780        63
#
#                                        PROD_NAME  PROD_QTY  TOT_SALES  \
# 73365             Cheetos Chs & Bacon Balls 190g         1        3.3
# ...

# %%
data_86 = data[data['STORE_NBR']==86]
data_86
# Out:
#         LYLTY_CARD_NBR        DATE  STORE_NBR  TXN_ID  PROD_NBR  \
# 82393            86000  26-08-2018         86   84137        90
# 82394            86000  25-09-2018         86   84138        88
# 82395            86000  19-02-2019         86   84139        41
# 82396            86000  20-11-2018         86   84140       111
# 82397            86000  30-11-2018         86   84141        13
# ...                ...         ...        ...     ...       ...
# 153415          155479  19-08-2018         86  155508        74
# 153416          155479  21-11-2018         86  155509         9
# 153417          155485  08-11-2018         86  155552        97
# 153418          155489  15-08-2018         86  155582        78
# 153419          155510  14-08-2018         86  155718        82
#
#                                       PROD_NAME  PROD_QTY  TOT_SALES  \
# 82393         Tostitos Smoked     Chipotle 175g         2        8.8
# ...

# %%
data_88 = data[data['STORE_NBR']==88]
data_88
# Out:
#         LYLTY_CARD_NBR        DATE  STORE_NBR  TXN_ID  PROD_NBR  \
# 84429            88000  12-09-2018         88   86220         4
# 84430            88000  26-10-2018         88   86221        31
# 84431            88000  02-02-2019         88   86222        46
# 84432            88000  01-05-2019         88   86223        47
# 84433            88000  02-05-2019         88   86224       102
# ...                ...         ...        ...     ...       ...
# 264829         2370701  08-12-2018         88  240378        24
# 264830         2370751  01-10-2018         88  240394        60
# 264831         2370961  24-10-2018         88  240480        70
# 264832         2370961  27-10-2018         88  240481        65
# 264833         2373711  14-12-2018         88  241815        16
#
#                                        PROD_NAME  PROD_QTY  TOT_SALES  \
# 84429           Dorito Corn Chp     Supreme 380g         2       13.0
# ...

# %%
data_77.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 563 entries, 73365 to 264822
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   LYLTY_CARD_NBR    563 non-null    int64
#  1   DATE              563 non-null    object
#  2   STORE_NBR         563 non-null    int64
#  3   TXN_ID            563 non-null    int64
#  4   PROD_NBR          563 non-null    int64
#  5   PROD_NAME         563 non-null    object
#  6   PROD_QTY          563 non-null    int64
#  7   TOT_SALES         563 non-null    float64
#  8   PACK_SIZE         563 non-null    int64
#  9   BRAND             563 non-null    object
#  10  LIFESTAGE         563 non-null    object
#  11  PREMIUM_CUSTOMER  563 non-null    object
# dtypes: float64(1), int64(6), object(5)
# memory usage: 57.2+ KB

# %%
data_77['DATE'] = pd.to_datetime(data_77['DATE'])
# Out:
# C:\Users\suskr\AppData\Local\Temp\ipykernel_11252\3563511711.py:1: UserWarning: Parsing dates in %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   data_77['DATE'] = pd.to_datetime(data_77['DATE'])
# C:\Users\suskr\AppData\Local\Temp\ipykernel_11252\3563511711.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_77['DATE'] = pd.to_datetime(data_77['DATE'])

# %%
data_77.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 563 entries, 73365 to 264822
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   LYLTY_CARD_NBR    563 non-null    int64
#  1   DATE              563 non-null    datetime64[ns]
#  2   STORE_NBR         563 non-null    int64
#  3   TXN_ID            563 non-null    int64
#  4   PROD_NBR          563 non-null    int64
#  5   PROD_NAME         563 non-null    object
#  6   PROD_QTY          563 non-null    int64
#  7   TOT_SALES         563 non-null    float64
#  8   PACK_SIZE         563 non-null    int64
#  9   BRAND             563 non-null    object
#  10  LIFESTAGE         563 non-null    object
#  11  PREMIUM_CUSTOMER  563 non-null    object
# dtypes: datetime64[ns](1), float64(1), int64(6), object(4)
# memory usage: 57.2+ KB

# %%
data_77['MONTH_ID'] = data_77['DATE'].dt.strftime('%Y%m')
# Out:
# C:\Users\suskr\AppData\Local\Temp\ipykernel_11252\1195593052.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_77['MONTH_ID'] = data_77['DATE'].dt.strftime('%Y%m')

# %%
data_77
# Out:
#         LYLTY_CARD_NBR       DATE  STORE_NBR  TXN_ID  PROD_NBR  \
# 73365            77000 2019-03-28         77   74911        18
# 73366            77000 2019-04-13         77   74912        69
# 73367            77000 2018-09-26         77   74910        36
# 73368            77001 2019-02-27         77   74913         7
# 73369            77001 2019-01-21         77   74914         9
# ...                ...        ...        ...     ...       ...
# 264818         2330321 2018-07-30         77  236756        71
# 264819         2330331 2018-11-18         77  236760        95
# 264820         2330431 2018-07-31         77  236770        50
# 264821         2330461 2018-07-21         77  236777        87
# 264822         2330501 2019-06-20         77  236780        63
#
#                                        PROD_NAME  PROD_QTY  TOT_SALES  \
# 73365             Cheetos Chs & Bacon Balls 190g         1        3.3
# ...

# %%
data_86['DATE'] = pd.to_datetime(data_86['DATE'])
# Out:
# C:\Users\suskr\AppData\Local\Temp\ipykernel_11252\927587293.py:1: UserWarning: Parsing dates in %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   data_86['DATE'] = pd.to_datetime(data_86['DATE'])
# C:\Users\suskr\AppData\Local\Temp\ipykernel_11252\927587293.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_86['DATE'] = pd.to_datetime(data_86['DATE'])

# %%
data_86.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1538 entries, 82393 to 153419
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   LYLTY_CARD_NBR    1538 non-null   int64
#  1   DATE              1538 non-null   datetime64[ns]
#  2   STORE_NBR         1538 non-null   int64
#  3   TXN_ID            1538 non-null   int64
#  4   PROD_NBR          1538 non-null   int64
#  5   PROD_NAME         1538 non-null   object
#  6   PROD_QTY          1538 non-null   int64
#  7   TOT_SALES         1538 non-null   float64
#  8   PACK_SIZE         1538 non-null   int64
#  9   BRAND             1538 non-null   object
#  10  LIFESTAGE         1538 non-null   object
#  11  PREMIUM_CUSTOMER  1538 non-null   object
# dtypes: datetime64[ns](1), float64(1), int64(6), object(4)
# memory usage: 156.2+ KB

# %%
data_86['MONTH_ID'] = data_86['DATE'].dt.strftime('%Y%m')
data_86
# Out:
# C:\Users\suskr\AppData\Local\Temp\ipykernel_11252\1508786020.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_86['MONTH_ID'] = data_86['DATE'].dt.strftime('%Y%m')
#         LYLTY_CARD_NBR       DATE  STORE_NBR  TXN_ID  PROD_NBR  \
# 82393            86000 2018-08-26         86   84137        90
# 82394            86000 2018-09-25         86   84138        88
# 82395            86000 2019-02-19         86   84139        41
# 82396            86000 2018-11-20         86   84140       111
# 82397            86000 2018-11-30         86   84141        13
# ...                ...        ...        ...     ...       ...
# 153415          155479 2018-08-19         86  155508        74
# ...

# %%
data_88['DATE'] = pd.to_datetime(data_88['DATE'], format='%d-%m-%Y')
# Out:
# C:\Users\suskr\AppData\Local\Temp\ipykernel_11252\3016849907.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_88['DATE'] = pd.to_datetime(data_88['DATE'], format='%d-%m-%Y')

# %%
data_88['MONTH_ID'] = data_88['DATE'].dt.strftime('%Y%m')
data_88
# Out:
# C:\Users\suskr\AppData\Local\Temp\ipykernel_11252\954612062.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_88['MONTH_ID'] = data_88['DATE'].dt.strftime('%Y%m')
#         LYLTY_CARD_NBR       DATE  STORE_NBR  TXN_ID  PROD_NBR  \
# 84429            88000 2018-09-12         88   86220         4
# 84430            88000 2018-10-26         88   86221        31
# 84431            88000 2019-02-02         88   86222        46
# 84432            88000 2019-05-01         88   86223        47
# 84433            88000 2019-05-02         88   86224       102
# ...                ...        ...        ...     ...       ...
# 264829         2370701 2018-12-08         88  240378        24
# ...

# %%
grouped_df_77 = data_77.groupby('MONTH_ID').agg({'TOT_SALES': 'sum', 'LYLTY_CARD_NBR': 'count'})

# %%
grouped_df_77
# Out:
#           TOT_SALES  LYLTY_CARD_NBR
# MONTH_ID
# 201807        296.8              55
# 201808        255.5              48
# 201809        225.2              44
# 201810        204.5              38
# 201811        245.3              44
# 201812        267.3              49
# 201901        204.4              39
# 201902        235.0              45
# 201903        278.5              55
# 201904        263.5              48
# 201905        299.3              56
# 201906        264.7              42

# %%
grouped_df_86 = data_86.groupby('MONTH_ID').agg({'TOT_SALES': 'sum', 'LYLTY_CARD_NBR': 'count'})
grouped_df_86
# Out:
#           TOT_SALES  LYLTY_CARD_NBR
# MONTH_ID
# 201807       892.20             126
# 201808       764.05             112
# 201809       914.60             129
# 201810       948.40             138
# 201811       918.00             127
# 201812       841.20             120
# 201901       841.40             130
# 201902       913.20             139
# 201903      1026.80             142
# 201904       848.20             127
# 201905       889.30             129
# 201906       838.00             119

# %%
grouped_df_88 = data_88.groupby('MONTH_ID').agg({'TOT_SALES': 'sum', 'LYLTY_CARD_NBR': 'count'})
grouped_df_88
# Out:
#           TOT_SALES  LYLTY_CARD_NBR
# MONTH_ID
# 201807      1310.00             153
# 201808      1323.80             160
# 201809      1423.00             159
# 201810      1352.40             158
# 201811      1382.80             157
# 201812      1325.20             149
# 201901      1266.40             146
# 201902      1370.20             154
# 201903      1477.20             170
# 201904      1439.40             162
# 201905      1308.25             155
# 201906      1354.60             150
